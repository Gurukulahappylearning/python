# %%
# decision making statements

# %%
# what are all decision making statements

# %%
# If syntax

# %% [markdown]
# ![if.png](attachment:if.png)# if flowchart

# %%
# Example if
x=4
if (x>3):
    print("lets go for movie")
# Out:
# lets go for movie

# %%
x=2
if (x>3):
    print("lets go for movie")
print("program terminated")
# Out:
# program terminated

# %%
x=2
if (x>3):
    print("lets go for movie")
if(x<3):
    print("lets go for bike ride")
    
print("program terminated")
print("if block executed")
# Out:
# lets go for bike ride
# program terminated
# if block executed

# %%
# if else syntax

# %% [markdown]
# ![if%20else.png](attachment:if%20else.png)# if else flowchart

# %%
# example if else

x=4

if (x>3):
    print("lets go for movie")
    
else:
    print("lets go for bike ride")
    
print("program terminated")
print("if block executed")
# Out:
# lets go for movie
# program terminated
# if block executed
